# %% [markdown]
# # Fast and efficient preprocessing of scRNA-seq with kallisto | bustools | kb-python
#
#
# This notebook provides a complete workflow to quantify single-cell RNA-seq data using using **kb-python** (kallisto|bustools).
#
#
# [Md. Jubayer Hossain](https://mdjubayerhossain.com/)
#
# Founder & CEO, [DeepBio Ltd.](https://deepbioltd.com/)

# %% [markdown]
# ## Step 1: Install Required Packages
#
# Install kb-python and ffq (for downloading SRA data).

# %%
# Install kb-python and ffq
# %%time
# !pip install kb-python ffq -q
# Out:
# CPU times: user 1.3 s, sys: 167 ms, total: 1.47 s
# Wall time: 5.08 s

# %%
# Mount Google Drive (only mounts if not mounted already)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set up main working directory
import os
working_dir = "/content/drive/MyDrive/01-Projects/Papers/AD-Sex-Differences"
os.makedirs(working_dir, exist_ok=True)
os.chdir(working_dir)

# %%
# Define folder structure
folders = [
    "reference",
    "raw_data",
    "processed_data",
    "results",
    "results/figures",
    "results/tables"
]

# Create folders
for folder in folders:
    path = os.path.join(working_dir, folder)
    os.makedirs(path, exist_ok=True)

# %%
# Set Save paths for easy use later
reference_dir = os.path.join(working_dir, "reference")
raw_data_dir = os.path.join(working_dir, "raw_data")
processed_data_dir = os.path.join(working_dir, "processed_data")
results_dir = os.path.join(working_dir, "results")
figures_dir = os.path.join(working_dir, "results/figures")
tables_dir = os.path.join(working_dir, "results/tables")

# %% [markdown]
# ## Step 2: Build Reference Index
#
# We'll use kb-python's built-in reference download for mouse. This will download the mouse transcriptome and create an index.
#
# Before we can quantify gene expression from raw FASTQ files, we need to create a reference index.
# This index is essential because tools like kb-python (Kallisto | Bustools) must know:
#
# - Which transcripts exist in the organism?
# - Where each transcript starts and ends?
# - Which transcripts map to which genes?
#
# This allows the reads to be pseudoaligned quickly and accurately.

# %%
# Check directory path
# !pwd
# Out:
# /content/drive/MyDrive/01-Projects/Papers/AD-Sex-Differences

# %%
# List directories
# !ls
# Out:
# notebooks  processed_data  raw_data  reference	results

# %%
# Check results
# !ls results
# Out:
# figures  tables

# %%
# Download and build mouse reference (this may take 10-15 minutes)
# For human: -d human
# For Mouse: -d mouse
# %%time
# !kb ref -d human -i reference/index.idx -g reference/t2g.txt
# Out:
# [2026-01-20 21:02:53,798]    INFO [download] Downloading files for human (standard workflow) from https://github.com/pachterlab/kallisto-transcriptome-indices/releases/download/v1/human_index_standard.tar.xz to tmp/human_index_standard.tar.xz
# 100% 138M/138M [00:01<00:00, 73.7MB/s]
# [2026-01-20 21:02:55,769]    INFO [download] Extracting files from tmp/human_index_standard.tar.xz
# CPU times: user 98.1 ms, sys: 18.4 ms, total: 116 ms
# Wall time: 44.5 s

# %% [markdown]
# This command downloads and builds the human transcriptome reference needed for `pseudoalignment` and count matrix generation in single-cell RNA-seq.
#
# - `kb ref` prepares everything needed for kb count, including:
#     - downloading the transcriptome
#     - generating the kallisto index
#     - building the transcript-to-gene (t2g) mapping file
#
# - `-d human`
#     - Tells `kb-python` to automatically download a predefined HUMAN reference dataset.
#     - No need to manually supply FASTA or GTF files.
#
# - `-i reference/index.idx`
#     - Specifies where to save the kallisto index, which is used for fast pseudoalignment.
# - `-g reference/t2g.txt`
#     - Creates a transcript-to-gene mapping file.
#     - Bustools uses this file to convert transcript counts into gene counts.

# %% [markdown]
# ### Alternative: Manual Reference Building
#
# If you prefer to build the reference manually from specific genome and GTF files:

# %%
# OPTIONAL: Manual reference building (uncomment to use)
# Download genome and GTF from Ensembl
# !wget ftp://ftp.ensembl.org/pub/release-109/fasta/mus_musculus/dna/Mus_musculus.GRCm39.dna.primary_assembly.fa.gz
# !wget ftp://ftp.ensembl.org/pub/release-109/gtf/mus_musculus/Mus_musculus.GRCm39.109.gtf.gz

# Build reference
# !kb ref \
#   -i reference/index.idx \
#   -g reference/t2g.txt \
#   -f1 reference/transcriptome.fa \
#   Mus_musculus.GRCm39.dna.primary_assembly.fa.gz \
#   Mus_musculus.GRCm39.109.gtf.gz

# %%
# Get sample information
import os
import json
import subprocess

# Sample IDs from the SRA project
samples = [
    "SRR10278808", "SRR10278809", "SRR10278810", "SRR10278811", "SRR10278812",
    "SRR10278813", "SRR10278814", "SRR10278815", "SRR10278816", "SRR10278817",
    "SRR10278818", "SRR10278819", "SRR10278820", "SRR10278821", "SRR10278822",
    "SRR10278823", "SRR10278824", "SRR10278825", "SRR10278826", "SRR10278827",
    "SRR10278828", "SRR10278829", "SRR10278830", "SRR10278831", "SRR10278832",
    "SRR10278833", "SRR10278834", "SRR10278835", "SRR10278836", "SRR10278838",
    "SRR10278839"
]

# Total samples
print(f"Total samples: {len(samples)}")

print("Samples to download:")
for sample in samples:
    print(f"  - {sample}")
# Out:
# Total samples: 31
# Samples to download:
#   - SRR10278808
#   - SRR10278809
#   - SRR10278810
#   - SRR10278811
#   - SRR10278812
#   - SRR10278813
#   - SRR10278814
#   - SRR10278815
#   - SRR10278816
#   - SRR10278817
#   - SRR10278818
#   - SRR10278819
#   - SRR10278820
#   - SRR10278821
#   - SRR10278822
#   - SRR10278823
#   - SRR10278824
#   - SRR10278825
#   - SRR10278826
#   - SRR10278827
#   - SRR10278828
#   - SRR10278829
#   - SRR10278830
#   - SRR10278831
#   - SRR10278832
#   - SRR10278833
#   - SRR10278834
#   - SRR10278835
#   - SRR10278836
#   - SRR10278838
#   - SRR10278839

# %%
# Download FASTQ files using ffq
# Note: This will download large files (20-40 GB total)
# Make sure you have sufficient disk space and time
# %%time
for sample in samples:
    print(f"\nDownloading {sample}...")

    # Get FTP URLs using ffq
    result = subprocess.run(
        ["ffq", "--ftp", sample],
        capture_output=True,
        text=True
    )

    # Parse the JSON output
    data = json.loads(result.stdout)

    # Download FASTQ files
    for entry in data:
        url = entry['url']
        filename = os.path.basename(url)
        output_path = f"raw_data/{filename}"

        if not os.path.exists(output_path):
            print(f"Downloading: {filename}")
            # !wget -q --show-progress -O {output_path} {url}
        else:
            print(f"File already exists: {filename}")
# Out:
# Downloading SRR10278808...
# Downloading: SRR10278808.fastq.gz
# SRR10278808.fastq.g 100%[===================>]   1.32G  39.4MB/s    in 40s
#
# Downloading SRR10278809...
# Downloading: SRR10278809.fastq.gz
# SRR10278809.fastq.g 100%[===================>]   1.32G  34.7MB/s    in 50s
#
# Downloading SRR10278810...
# Downloading: SRR10278810.fastq.gz
# SRR10278810.fastq.g 100%[===================>]   1.32G  39.1MB/s    in 46s
#
# Downloading SRR10278811...
# Downloading: SRR10278811.fastq.gz
# SRR10278811.fastq.g 100%[===================>]   1.32G  38.3MB/s    in 43s
#
# Downloading SRR10278812...
# Downloading: SRR10278812.fastq.gz
# SRR10278812.fastq.g 100%[===================>]   1.26G  39.3MB/s    in 41s
#
# Downloading SRR10278813...
# Downloading: SRR10278813.fastq.gz
# SRR10278813.fastq.g 100%[===================>]   1.26G  24.9MB/s    in 57s
#
# Downloading SRR10278814...
# Downloading: SRR10278814.fastq.gz
# SRR10278814.fastq.g 100%[===================>]   1.26G  34.6MB/s    in 45s
#
# Downloading SRR10278815...
# Downloading: SRR10278815.fastq.gz
# SRR10278815.fastq.g 100%[===================>]   1.26G  20.5MB/s    in 54s
#
# Downloading SRR10278816...
# Downloading: SRR10278816.fastq.gz
# SRR10278816.fastq.g 100%[===================>]   1.33G  30.4MB/s    in 48s
#
# Downloading SRR10278817...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.12/json/decoder.py in decode(self, s, _w)
#     336
#     337         """
# --> 338         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339         end = _w(s, end).end()
#     340         if end != len(s):
#
# /usr/lib/python3.12/json/decoder.py in raw_decode(self, s, idx)
#     354             obj, end = self.scan_once(s, idx)
#     355         except StopIteration as err:
# --> 356             raise JSONDecodeError("Expecting value", s, err.value) from None
#     357         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### Alternative: Use SRA Toolkit (if ffq has issues)

# %%
# ALTERNATIVE: Download using SRA toolkit
# !pip install sra-tools -q

# for sample in samples:
#     print(f"Downloading {sample}...")
#     !fastq-dump --split-files --gzip --outdir raw_data {sample}

# %% [markdown]
# ## Step 4: Quantify with kb-python (Pseudoalignment and UMI counting)
#
# Now we'll use kb count to process the FASTQ files. Since this is 10x Chromium data, we'll use the `10xv2/v3` technology specification.

# %%
# Process each sample
# This step runs `kb` to pseudoalign the reads, and then generate the cells x gene matrix in h5ad format.
# %%time
for sample in samples:
    print(f"\n{'='*60}")
    print(f"Processing sample: {sample}")
    print(f"{'='*60}\n")

    # Define input and output paths
    r1 = f"raw_data/{sample}_1.fastq.gz"
    r2 = f"raw_data/{sample}_2.fastq.gz"
    output_dir = f"output/{sample}"

    # Run kb count
    # Note: Adjust -x parameter if needed (try 10xv3 if 10xv2 doesn't work well)
    # !kb count \
        -i reference/index.idx \
        -g reference/t2g.txt \
        -x 10xv3 \
        -o {output_dir} \
        --h5ad \
        -t 4 \
        {r1} {r2}

    print(f"\nCompleted processing: {sample}")
    print(f"Output directory: {output_dir}")
# Out:
# ============================================================
# Processing sample: SRR10278808
# ============================================================
#
# [2026-01-20 21:11:26,392]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278808 from
# [2026-01-20 21:11:26,392]    INFO [count]         raw_data/SRR10278808_1.fastq.gz
# [2026-01-20 21:11:26,392]    INFO [count]         raw_data/SRR10278808_2.fastq.gz
# [2026-01-20 21:11:27,495]   ERROR [count]
# Error: file not found raw_data/SRR10278808_1.fastq.gz
# Error: file not found raw_data/SRR10278808_2.fastq.gz
# kallisto 0.51.1
# Warning: you asked for 4, but only 2 cores on the machine
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:11:27,496]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278808 -x 10xv3 -t 4 raw_data/SRR10278808_1.fastq.gz raw_data/SRR10278808_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278808
# Output directory: output/SRR10278808
#
# ============================================================
# Processing sample: SRR10278809
# ============================================================
#
# [2026-01-20 21:11:36,736]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278809 from
# [2026-01-20 21:11:36,736]    INFO [count]         raw_data/SRR10278809_1.fastq.gz
# [2026-01-20 21:11:36,736]    INFO [count]         raw_data/SRR10278809_2.fastq.gz
# [2026-01-20 21:11:37,839]   ERROR [count]
# Error: file not found raw_data/SRR10278809_1.fastq.gz
# Error: file not found raw_data/SRR10278809_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:11:37,840]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278809 -x 10xv3 -t 4 raw_data/SRR10278809_1.fastq.gz raw_data/SRR10278809_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278809
# Output directory: output/SRR10278809
#
# ============================================================
# Processing sample: SRR10278810
# ============================================================
#
# [2026-01-20 21:11:47,055]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278810 from
# [2026-01-20 21:11:47,055]    INFO [count]         raw_data/SRR10278810_1.fastq.gz
# [2026-01-20 21:11:47,056]    INFO [count]         raw_data/SRR10278810_2.fastq.gz
# [2026-01-20 21:11:48,161]   ERROR [count]
# Error: file not found raw_data/SRR10278810_1.fastq.gz
# Error: file not found raw_data/SRR10278810_2.fastq.gz
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# Warning: you asked for 4, but only 2 cores on the machine
# [2026-01-20 21:11:48,161]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278810 -x 10xv3 -t 4 raw_data/SRR10278810_1.fastq.gz raw_data/SRR10278810_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278810
# Output directory: output/SRR10278810
#
# ============================================================
# Processing sample: SRR10278811
# ============================================================
#
# [2026-01-20 21:11:57,816]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278811 from
# [2026-01-20 21:11:57,817]    INFO [count]         raw_data/SRR10278811_1.fastq.gz
# [2026-01-20 21:11:57,817]    INFO [count]         raw_data/SRR10278811_2.fastq.gz
# [2026-01-20 21:11:58,918]   ERROR [count]
# Error: file not found raw_data/SRR10278811_1.fastq.gz
# Error: file not found raw_data/SRR10278811_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:11:58,918]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278811 -x 10xv3 -t 4 raw_data/SRR10278811_1.fastq.gz raw_data/SRR10278811_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278811
# Output directory: output/SRR10278811
#
# ============================================================
# Processing sample: SRR10278812
# ============================================================
#
# [2026-01-20 21:12:08,825]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278812 from
# [2026-01-20 21:12:08,825]    INFO [count]         raw_data/SRR10278812_1.fastq.gz
# [2026-01-20 21:12:08,825]    INFO [count]         raw_data/SRR10278812_2.fastq.gz
# [2026-01-20 21:12:09,927]   ERROR [count]
# Error: file not found raw_data/SRR10278812_1.fastq.gz
# Error: file not found raw_data/SRR10278812_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:12:09,927]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278812 -x 10xv3 -t 4 raw_data/SRR10278812_1.fastq.gz raw_data/SRR10278812_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278812
# Output directory: output/SRR10278812
#
# ============================================================
# Processing sample: SRR10278813
# ============================================================
#
# [2026-01-20 21:12:19,578]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278813 from
# [2026-01-20 21:12:19,578]    INFO [count]         raw_data/SRR10278813_1.fastq.gz
# [2026-01-20 21:12:19,578]    INFO [count]         raw_data/SRR10278813_2.fastq.gz
# [2026-01-20 21:12:20,680]   ERROR [count]
# Error: file not found raw_data/SRR10278813_1.fastq.gz
# Error: file not found raw_data/SRR10278813_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:12:20,680]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278813 -x 10xv3 -t 4 raw_data/SRR10278813_1.fastq.gz raw_data/SRR10278813_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278813
# Output directory: output/SRR10278813
#
# ============================================================
# Processing sample: SRR10278814
# ============================================================
#
# [2026-01-20 21:12:30,910]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278814 from
# [2026-01-20 21:12:30,910]    INFO [count]         raw_data/SRR10278814_1.fastq.gz
# [2026-01-20 21:12:30,910]    INFO [count]         raw_data/SRR10278814_2.fastq.gz
# [2026-01-20 21:12:32,011]   ERROR [count]
# Error: file not found raw_data/SRR10278814_1.fastq.gz
# Error: file not found raw_data/SRR10278814_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:12:32,011]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278814 -x 10xv3 -t 4 raw_data/SRR10278814_1.fastq.gz raw_data/SRR10278814_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278814
# Output directory: output/SRR10278814
#
# ============================================================
# Processing sample: SRR10278815
# ============================================================
#
# [2026-01-20 21:12:41,292]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278815 from
# [2026-01-20 21:12:41,292]    INFO [count]         raw_data/SRR10278815_1.fastq.gz
# [2026-01-20 21:12:41,292]    INFO [count]         raw_data/SRR10278815_2.fastq.gz
# [2026-01-20 21:12:42,396]   ERROR [count]
# Error: file not found raw_data/SRR10278815_1.fastq.gz
# Error: file not found raw_data/SRR10278815_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:12:42,396]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278815 -x 10xv3 -t 4 raw_data/SRR10278815_1.fastq.gz raw_data/SRR10278815_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278815
# Output directory: output/SRR10278815
#
# ============================================================
# Processing sample: SRR10278816
# ============================================================
#
# [2026-01-20 21:12:51,766]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278816 from
# [2026-01-20 21:12:51,767]    INFO [count]         raw_data/SRR10278816_1.fastq.gz
# [2026-01-20 21:12:51,767]    INFO [count]         raw_data/SRR10278816_2.fastq.gz
# [2026-01-20 21:12:52,868]   ERROR [count]
# Error: file not found raw_data/SRR10278816_1.fastq.gz
# Error: file not found raw_data/SRR10278816_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:12:52,868]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278816 -x 10xv3 -t 4 raw_data/SRR10278816_1.fastq.gz raw_data/SRR10278816_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278816
# Output directory: output/SRR10278816
#
# ============================================================
# Processing sample: SRR10278817
# ============================================================
#
# [2026-01-20 21:13:02,733]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278817 from
# [2026-01-20 21:13:02,733]    INFO [count]         raw_data/SRR10278817_1.fastq.gz
# [2026-01-20 21:13:02,733]    INFO [count]         raw_data/SRR10278817_2.fastq.gz
# [2026-01-20 21:13:03,834]   ERROR [count]
# Error: file not found raw_data/SRR10278817_1.fastq.gz
# Error: file not found raw_data/SRR10278817_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:13:03,835]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278817 -x 10xv3 -t 4 raw_data/SRR10278817_1.fastq.gz raw_data/SRR10278817_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278817
# Output directory: output/SRR10278817
#
# ============================================================
# Processing sample: SRR10278818
# ============================================================
#
# [2026-01-20 21:13:13,941]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278818 from
# [2026-01-20 21:13:13,941]    INFO [count]         raw_data/SRR10278818_1.fastq.gz
# [2026-01-20 21:13:13,941]    INFO [count]         raw_data/SRR10278818_2.fastq.gz
# [2026-01-20 21:13:15,043]   ERROR [count]
# Error: file not found raw_data/SRR10278818_1.fastq.gz
# Error: file not found raw_data/SRR10278818_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:13:15,043]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278818 -x 10xv3 -t 4 raw_data/SRR10278818_1.fastq.gz raw_data/SRR10278818_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278818
# Output directory: output/SRR10278818
#
# ============================================================
# Processing sample: SRR10278819
# ============================================================
#
# [2026-01-20 21:13:24,686]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278819 from
# [2026-01-20 21:13:24,687]    INFO [count]         raw_data/SRR10278819_1.fastq.gz
# [2026-01-20 21:13:24,687]    INFO [count]         raw_data/SRR10278819_2.fastq.gz
# [2026-01-20 21:13:25,788]   ERROR [count]
# Error: file not found raw_data/SRR10278819_1.fastq.gz
# Error: file not found raw_data/SRR10278819_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:13:25,788]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278819 -x 10xv3 -t 4 raw_data/SRR10278819_1.fastq.gz raw_data/SRR10278819_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278819
# Output directory: output/SRR10278819
#
# ============================================================
# Processing sample: SRR10278820
# ============================================================
#
# [2026-01-20 21:13:36,233]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278820 from
# [2026-01-20 21:13:36,234]    INFO [count]         raw_data/SRR10278820_1.fastq.gz
# [2026-01-20 21:13:36,234]    INFO [count]         raw_data/SRR10278820_2.fastq.gz
# [2026-01-20 21:13:37,335]   ERROR [count]
# Error: file not found raw_data/SRR10278820_1.fastq.gz
# Error: file not found raw_data/SRR10278820_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:13:37,336]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
# ...
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278834 -x 10xv3 -t 4 raw_data/SRR10278834_1.fastq.gz raw_data/SRR10278834_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278834
# Output directory: output/SRR10278834
#
# ============================================================
# Processing sample: SRR10278835
# ============================================================
#
# [2026-01-20 21:16:24,961]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278835 from
# [2026-01-20 21:16:24,961]    INFO [count]         raw_data/SRR10278835_1.fastq.gz
# [2026-01-20 21:16:24,961]    INFO [count]         raw_data/SRR10278835_2.fastq.gz
# [2026-01-20 21:16:26,063]   ERROR [count]
# Error: file not found raw_data/SRR10278835_1.fastq.gz
# Error: file not found raw_data/SRR10278835_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:16:26,063]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278835 -x 10xv3 -t 4 raw_data/SRR10278835_1.fastq.gz raw_data/SRR10278835_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278835
# Output directory: output/SRR10278835
#
# ============================================================
# Processing sample: SRR10278836
# ============================================================
#
# [2026-01-20 21:16:35,374]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278836 from
# [2026-01-20 21:16:35,374]    INFO [count]         raw_data/SRR10278836_1.fastq.gz
# [2026-01-20 21:16:35,374]    INFO [count]         raw_data/SRR10278836_2.fastq.gz
# [2026-01-20 21:16:36,476]   ERROR [count]
# Error: file not found raw_data/SRR10278836_1.fastq.gz
# Error: file not found raw_data/SRR10278836_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:16:36,476]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278836 -x 10xv3 -t 4 raw_data/SRR10278836_1.fastq.gz raw_data/SRR10278836_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278836
# Output directory: output/SRR10278836
#
# ============================================================
# Processing sample: SRR10278838
# ============================================================
#
# [2026-01-20 21:16:46,685]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278838 from
# [2026-01-20 21:16:46,686]    INFO [count]         raw_data/SRR10278838_1.fastq.gz
# [2026-01-20 21:16:46,686]    INFO [count]         raw_data/SRR10278838_2.fastq.gz
# [2026-01-20 21:16:47,787]   ERROR [count]
# Error: file not found raw_data/SRR10278838_1.fastq.gz
# Error: file not found raw_data/SRR10278838_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:16:47,787]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278838 -x 10xv3 -t 4 raw_data/SRR10278838_1.fastq.gz raw_data/SRR10278838_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278838
# Output directory: output/SRR10278838
#
# ============================================================
# Processing sample: SRR10278839
# ============================================================
#
# [2026-01-20 21:16:57,370]    INFO [count] Using index reference/index.idx to generate BUS file to output/SRR10278839 from
# [2026-01-20 21:16:57,370]    INFO [count]         raw_data/SRR10278839_1.fastq.gz
# [2026-01-20 21:16:57,370]    INFO [count]         raw_data/SRR10278839_2.fastq.gz
# [2026-01-20 21:16:58,471]   ERROR [count]
# Error: file not found raw_data/SRR10278839_1.fastq.gz
# Error: file not found raw_data/SRR10278839_2.fastq.gz
# Warning: you asked for 4, but only 2 cores on the machine
# kallisto 0.51.1
# Generates BUS files for single-cell sequencing
#
# Usage: kallisto bus [arguments] FASTQ-files
#
# Required arguments:
# -i, --index=STRING            Filename for the kallisto index to be used for
# pseudoalignment
# -o, --output-dir=STRING       Directory to write output to
#
# Optional arguments:
# -x, --technology=STRING       Single-cell technology used
# -l, --list                    List all single-cell technologies supported
# -B, --batch=FILE              Process files listed in FILE
# -t, --threads=INT             Number of threads to use (default: 1)
# -b, --bam                     Input file is a BAM file
# -n, --num                     Output number of read in flag column (incompatible with --bam)
# -N, --numReads                Maximum number of reads to process from supplied input
# -T, --tag=STRING              5′ tag sequence to identify UMI reads for certain technologies
# --fr-stranded             Strand specific reads for UMI-tagged reads, first read forward
# --rf-stranded             Strand specific reads for UMI-tagged reads, first read reverse
# --unstranded              Treat all read as non-strand-specific
# --paired                  Treat reads as paired
# --long                    Treat reads as long
# --threshold               Threshold for rate of unmapped kmers per read
# --aa                      Align to index generated from a FASTA-file containing amino acid sequences
# --inleaved                Specifies that input is an interleaved FASTQ file
# --batch-barcodes          Records both batch and extracted barcode in BUS file
# --verbose                 Print out progress information every 1M proccessed reads
# [2026-01-20 21:16:58,472]   ERROR [main] An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 1933, in main
#     COMMAND_TO_FUNCTION[args.command](parser, args, temp_dir=temp_dir)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/main.py", line 715, in parse_count
#     count(
#   File "/usr/local/lib/python3.12/dist-packages/ngs_tools/logging.py", line 62, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 1350, in count
#     bus_result = kallisto_bus(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/count.py", line 244, in kallisto_bus
#     run_executable(command)
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/dry/__init__.py", line 25, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kb_python/utils.py", line 203, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.12/dist-packages/kb_python/bins/linux/kallisto/kallisto bus -i reference/index.idx -o output/SRR10278839 -x 10xv3 -t 4 raw_data/SRR10278839_1.fastq.gz raw_data/SRR10278839_2.fastq.gz' returned non-zero exit status 1.
#
# Completed processing: SRR10278839
# Output directory: output/SRR10278839
# CPU times: user 892 ms, sys: 134 ms, total: 1.03 s
# Wall time: 5min 46s

# %% [markdown]
# **Understanding kb count parameters:**
#
# - `-i`: Index file created in Step 2
# - `-g`: Transcript-to-gene mapping file
# - `-x 10xv3`: Technology specification (10x Chromium v3)
# - `-o`: Output directory
# - `--h5ad`: Generate AnnData h5ad file for easy loading in Python
# - `-t 4`: Use 4 threads (adjust based on available resources)
# - Last arguments: Read 1 and Read 2 FASTQ files
